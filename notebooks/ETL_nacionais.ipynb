# %%
# ==============================================================================
# Importar as bibliotecas necessárias para manipulação,
# análise e visualização inicial dos dados.
# ==============================================================================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import ipykernel as ipk

# %%
#Leitura dos arquivos CSV do projeto
df_nacionais_limpo = pd.read_csv("../data/raw/pesquisa_nacional_atualizado.csv", sep=";")

# %%
# Descobrindo o tamanho do dataset
display(df_nacionais_limpo.shape)
# Out:
# (130, 33)

# %%
# Informações gerais sobre o DataFrame, incluindo o número de entradas, tipos de dados e contagem de valores não nulos
df_nacionais_limpo.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id_registro              130 non-null    int64
#  1   marca                    130 non-null    str
#  2   linha                    130 non-null    str
#  3   produto                  130 non-null    str
#  4   nome_tom                 130 non-null    str
#  5   subtom                   130 non-null    str
#  6   categoria_tom_marca      130 non-null    str
#  7   codigo_hex               130 non-null    str
#  8   rgb_r                    130 non-null    int64
#  9   rgb_g                    130 non-null    int64
#  10  rgb_b                    130 non-null    int64
#  11  luminosidade_relativa    130 non-null    str
#  12  luminosidade_pct         130 non-null    str
#  13  grupo_luminosidade       130 non-null    str
#  14  peso_volume              130 non-null    str
#  15  unidade                  130 non-null    str
#  16  cobertura                130 non-null    str
#  17  acabamento               130 non-null    str
#  18  textura                  130 non-null    str
#  19  tipo_pele                130 non-null    str
#  20  vegano                   130 non-null    str
#  21  cruelty_free             130 non-null    str
#  22  fps                      130 non-null    str
#  23  ativo_destaque           130 non-null    str
#  24  tipo_hex                 130 non-null    str
#  25  fonte_oficial            130 non-null    str
#  26  fonte_swatch             130 non-null    str
#  27  imagem_swatch_url        130 non-null    str
#  28  data_coleta              130 non-null    str
#  29  status_qualidade         130 non-null    str
#  30  observacao_metodologica  130 non-null    str
#  31  fase_coleta              130 non-null    str
#  32  versao_regua             130 non-null    str
# dtypes: int64(4), str(29)
# memory usage: 33.6 KB

# %%
# Visualizando as primeiras linhas do DataFrame para ter uma ideia dos dados contidos nele
df_nacionais_limpo.head(5)
# Out:
#    id_registro        marca                   linha  \
# 0            1  O Boticário  Make B. Mate Salicylic
# 1            2  O Boticário  Make B. Mate Salicylic
# 2            3  O Boticário  Make B. Mate Salicylic
# 3            4  O Boticário  Make B. Mate Salicylic
# 4            5  O Boticário  Make B. Mate Salicylic
#
#                            produto nome_tom  \
# 0  Base Líquida Mate Salicylic 30g  Cor 100
# 1  Base Líquida Mate Salicylic 30g  Cor 110
# 2  Base Líquida Mate Salicylic 30g  Cor 120
# 3  Base Líquida Mate Salicylic 30g  Cor 130
# 4  Base Líquida Mate Salicylic 30g  Cor 140
#
#                                 subtom categoria_tom_marca codigo_hex  rgb_r  \
# 0  Não informado pela fonte consultada       Régua 24 tons    #BE9F8A    190
# 1  Não informado pela fonte consultada       Régua 24 tons    #C19C82    193
# 2  Não informado pela fonte consultada       Régua 24 tons    #BF9B81    191
# 3  Não informado pela fonte consultada       Régua 24 tons    #C49B7E    196
# 4  Não informado pela fonte consultada       Régua 24 tons    #BE987E    190
#
#    rgb_g  ...    ativo_destaque                           tipo_hex  \
# 0    159  ...  Ácido salicílico  Amostral digital — cartela visual
# 1    156  ...  Ácido salicílico  Amostral digital — cartela visual
# 2    155  ...  Ácido salicílico  Amostral digital — cartela visual
# 3    155  ...  Ácido salicílico  Amostral digital — cartela visual
# 4    152  ...  Ácido salicílico  Amostral digital — cartela visual
#
#                                        fonte_oficial  \
# 0  https://www.boticario.com.br/base-liquida-cor-...
# 1  https://www.boticario.com.br/base-liquida-cor-...
# 2  https://www.boticario.com.br/base-liquida-cor-...
# 3  https://www.boticario.com.br/base-liquida-cor-...
# 4  https://www.boticario.com.br/base-liquida-cor-...
#
#                                         fonte_swatch  \
# 0  https://http2.mlstatic.com/D_NQ_NP_832018-MLU7...
# 1  https://http2.mlstatic.com/D_NQ_NP_832018-MLU7...
# 2  https://http2.mlstatic.com/D_NQ_NP_832018-MLU7...
# 3  https://http2.mlstatic.com/D_NQ_NP_832018-MLU7...
# 4  https://http2.mlstatic.com/D_NQ_NP_832018-MLU7...
#
#                                    imagem_swatch_url data_coleta  \
# 0  https://http2.mlstatic.com/D_NQ_NP_832018-MLU7...  2026-08-10
# 1  https://http2.mlstatic.com/D_NQ_NP_832018-MLU7...  2026-08-10
# 2  https://http2.mlstatic.com/D_NQ_NP_832018-MLU7...  2026-08-10
# 3  https://http2.mlstatic.com/D_NQ_NP_832018-MLU7...  2026-08-10
# 4  https://http2.mlstatic.com/D_NQ_NP_832018-MLU7...  2026-08-10
#
#                                     status_qualidade  \
# 0  Validado sem nulos; RGB/HEX derivados de swatc...
# 1  Validado sem nulos; RGB/HEX derivados de swatc...
# 2  Validado sem nulos; RGB/HEX derivados de swatc...
# 3  Validado sem nulos; RGB/HEX derivados de swatc...
# 4  Validado sem nulos; RGB/HEX derivados de swatc...
#
#                              observacao_metodologica fase_coleta  \
# 0  Registro preservado da Fase 1. HEX é proxy vis...      Fase 1
# 1  Registro preservado da Fase 1. HEX é proxy vis...      Fase 1
# 2  Registro preservado da Fase 1. HEX é proxy vis...      Fase 1
# 3  Registro preservado da Fase 1. HEX é proxy vis...      Fase 1
# 4  Registro preservado da Fase 1. HEX é proxy vis...      Fase 1
#
#     versao_regua
# 0  Régua 24 tons
# 1  Régua 24 tons
# 2  Régua 24 tons
# 3  Régua 24 tons
# 4  Régua 24 tons
#
# [5 rows x 33 columns]

# %%
# Listando as colunas do DataFrame para entender a estrutura dos dados
display(list(df_nacionais_limpo.columns))
# Out:
# ['id_registro',
#  'marca',
#  'linha',
#  'produto',
#  'nome_tom',
#  'subtom',
#  'categoria_tom_marca',
#  'codigo_hex',
#  'rgb_r',
#  'rgb_g',
#  'rgb_b',
#  'luminosidade_relativa',
#  'luminosidade_pct',
#  'grupo_luminosidade',
#  'peso_volume',
#  'unidade',
#  'cobertura',
#  'acabamento',
#  'textura',
#  'tipo_pele',
#  'vegano',
#  'cruelty_free',
#  'fps',
#  'ativo_destaque',
#  'tipo_hex',
#  'fonte_oficial',
#  'fonte_swatch',
#  'imagem_swatch_url',
#  'data_coleta',
#  'status_qualidade',
#  'observacao_metodologica',
#  'fase_coleta',
#  'versao_regua']

# %%
# Renomeia a coluna produto para id_produto_marca
df_nacionais_limpo.rename(columns={'produto': 'id_produto_marca'}, inplace=True)

# %%
# Salva o CSV na pasta processed
df_nacionais_limpo.to_csv('../data/processed/df_nacionais_limpo.csv', index=False)
